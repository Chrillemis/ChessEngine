# %%
import os
import time
from tqdm.notebook import tqdm

# %%
# def progress():
    
#     while prog < 100:
#         yield prog

from tqdm import tqdm
import time

progress = 0

with tqdm(total=100) as pbar:
    while progress < 100:
        time.sleep(0.1)  # simulate update
        # progress += 1

        pbar.n = len(os.listdir("../data/preparedData/"))/len(os.listdir("../data/rawData/"))*100/2
        if len(os.listdir("../data/preparedData/"))/len(os.listdir("../data/rawData/"))*100/2 >= 100:
            break
        pbar.refresh()
# Out:
# 100%|██████████| 100.0/100 [00:01<00:00, 73.31it/s]
